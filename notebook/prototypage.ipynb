# %% [markdown]
# Importer les librairies dans le notebook

# %%
pip install ollama
# Out:
# Requirement already satisfied: ollama in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from httpx>=0.27->ollama) (4.12.0)
# Requirement already satisfied: certifi in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from httpx>=0.27->ollama) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ollama
import psycopg
from psycopg import Cursor
import os
import glob

# %% [markdown]
# Configuration

# %%
data_dir = os.path.join(os.path.dirname(os.getcwd()), "data")

OLLAMA_MODEL = "nomic-embed-text"

db_connection_str = "postgresql://postgres:postgres@localhost:5433/ai"

print(f"✓ Dossier de données : {data_dir}")
print(f"✓ Modèle Ollama : {OLLAMA_MODEL}")
print(f"✓ Configuration chargée")
# Out:
# ✓ Dossier de données : c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data
# ✓ Modèle Ollama : nomic-embed-text
# ✓ Configuration chargée

# %% [markdown]
# Test de connexion Ollama

# %%
try:
    models = ollama.list()
    
    # Extraire correctement tous les noms disponibles
    if isinstance(models, dict) and 'models' in models:
        model_names = [m.get('name') or m.get('model') for m in models['models']]
    elif isinstance(models, list):
        model_names = [m.get('name') or m.get('model') for m in models]
    else:
        model_names = []

    if OLLAMA_MODEL in model_names:
        print(f"✓ Modèle {OLLAMA_MODEL} disponible")
    else:
        print(f"⚠️  Modèle {OLLAMA_MODEL} non trouvé")
        print("   Modèles disponibles :", ", ".join(model_names))

    # Test embeddings
    print("\n🧪 Test d'embedding...")
    test_response = ollama.embeddings(model=OLLAMA_MODEL, prompt="test")
    print(f"✓ Ollama fonctionne correctement")

except Exception as e:
    print(f"❌ Erreur de connexion à Ollama : {e}")
# Out:
# ⚠️  Modèle nomic-embed-text non trouvé
#    Modèles disponibles :
#
# 🧪 Test d'embedding...
# ✓ Ollama fonctionne correctement

# %% [markdown]
# Fonctions utilitaires

# %%
def create_conversation_list(file_path: str) -> list[str]:
    """Lit le fichier avec le bon encodage et filtre les lignes"""
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
    except UnicodeDecodeError:
        print(f"⚠️  Encodage UTF-8 invalide pour {file_path} — réessayage avec cp1252")
        with open(file_path, "r", encoding="cp1252", errors="replace") as file:
            text = file.read()

    text_list = text.split("\n")
    filtered_list = [
        chaine.removeprefix("     ")
        for chaine in text_list
        if not chaine.startswith("<") and chaine.strip()
    ]
    print(f"✓ {len(filtered_list)} lignes extraites")
    return filtered_list


def calculate_embeddings(corpus: str) -> list[float]:
    """Calcule les embeddings avec Ollama"""
    if not corpus or not corpus.strip():
        raise ValueError("Le corpus ne peut pas être vide")
    
    # Appel à Ollama pour générer l'embedding
    response = ollama.embeddings(
        model=OLLAMA_MODEL,
        prompt=corpus
    )
    return response["embedding"]


def save_embedding(corpus: str, embedding: list[float], cursor: Cursor) -> None:
    """Sauvegarde le corpus et son embedding"""
    cursor.execute(
        '''INSERT INTO embeddings (corpus, embedding) VALUES (%s, %s)''',
        (corpus, embedding)
    )


def similar_corpus(input_corpus: str, db_connection_str: str, top_k: int = 5) -> list[tuple]:
    """
    Recherche les textes similaires dans la base de données
    """
    query_embedding = calculate_embeddings(input_corpus)
    
    with psycopg.connect(db_connection_str) as conn:
        with conn.cursor() as cur:
            cur.execute("""
                SELECT id, corpus, 
                       1 - (embedding <=> %s::vector) as similarity
                FROM embeddings
                ORDER BY embedding <=> %s::vector
                LIMIT %s
            """, (query_embedding, query_embedding, top_k))
            
            return cur.fetchall()

print("✓ Fonctions définies")
# Out:
# ✓ Fonctions définies

# %% [markdown]
# Test de génération d'embedding

# %%
try:
    test_text = "Ceci est un test d'embedding"
    test_embedding = calculate_embeddings(test_text)
    print(f"✓ Test réussi !")
    print(f"  Texte : '{test_text}'")
    print(f"  Dimension de l'embedding : {len(test_embedding)}")
    print(f"  Premiers valeurs : {test_embedding[:5]}")
    
    # Stocker la dimension pour la création de table
    EMBEDDING_DIM = len(test_embedding)
    print(f"\n✓ Dimension détectée : {EMBEDDING_DIM}")
except Exception as e:
    print(f"❌ Erreur lors du test : {e}")
    EMBEDDING_DIM = 768  # Valeur par défaut pour mistral
# Out:
# ✓ Test réussi !
#   Texte : 'Ceci est un test d'embedding'
#   Dimension de l'embedding : 768
#   Premiers valeurs : [0.9063271880149841, 1.077868938446045, -2.7506723403930664, -1.8096532821655273, 1.1117374897003174]
#
# ✓ Dimension détectée : 768

# %% [markdown]
# Création de la base de données

# %%
print("=" * 70)
print("🚀 CRÉATION DE LA BASE D'EMBEDDINGS")
print("=" * 70)

with psycopg.connect(db_connection_str) as conn:
    conn.autocommit = True
    with conn.cursor() as cur:
        # Supprimer l'index d'abord (pour éviter les erreurs)
        cur.execute("""DROP INDEX IF EXISTS embeddings_embedding_idx""")
        print("✓ Index existant supprimé")
        
        # Supprimer la table si elle existe
        cur.execute("""DROP TABLE IF EXISTS embeddings CASCADE""")
        print("✓ Table existante supprimée")
        
        # Créer l'extension pgvector
        cur.execute("""CREATE EXTENSION IF NOT EXISTS vector""")
        print("✓ Extension pgvector créée")
        
        # Créer la table avec la dimension détectée
        cur.execute(f"""
            CREATE TABLE embeddings (
                id SERIAL PRIMARY KEY, 
                corpus TEXT,
                embedding VECTOR({EMBEDDING_DIM})
            )
        """)
        print(f"✓ Table embeddings créée avec VECTOR({EMBEDDING_DIM})")
        
        # Créer un index pour accélérer les recherches
        # Note: L'index sera créé après l'insertion des données pour de meilleures performances
        print("✓ Table prête (l'index sera créé après insertion)")
# Out:
# ======================================================================
# 🚀 CRÉATION DE LA BASE D'EMBEDDINGS
# ======================================================================
# ✓ Index existant supprimé
# ✓ Table existante supprimée
# ✓ Extension pgvector créée
# ✓ Table embeddings créée avec VECTOR(768)
# ✓ Table prête (l'index sera créé après insertion)

# %% [markdown]
# Chargement des fichiers

# %%
print("\n" + "=" * 70)
print("📂 CHARGEMENT DES DONNÉES")
print("=" * 70)

text_files = sorted(glob.glob(os.path.join(data_dir, "*.txt")))

if not text_files:
    print(f"⚠️  Aucun fichier .txt trouvé dans le dossier {data_dir}")
else:
    print(f"✓ {len(text_files)} fichier(s) trouvé(s)")
    for i, file in enumerate(text_files[:5], 1):  # Afficher les 5 premiers
        print(f"  {i}. {os.path.basename(file)}")
    if len(text_files) > 5:
        print(f"  ... et {len(text_files) - 5} autre(s)")
# Out:
# ======================================================================
# 📂 CHARGEMENT DES DONNÉES
# ======================================================================
# ✓ 41 fichier(s) trouvé(s)
#   1. 017_00000012.txt
#   2. 018_00000013.txt
#   3. 019_00000014.txt
#   4. 020_00000015.txt
#   5. 022_00000017.txt
#   ... et 36 autre(s)

# %% [markdown]
# Traitement des embeddings

# %%
print("\n" + "=" * 70)
print("⚙️  TRAITEMENT DES EMBEDDINGS")
print("=" * 70)

success_count = 0
error_count = 0

with psycopg.connect(db_connection_str) as conn:
    conn.autocommit = True
    with conn.cursor() as cur:
        total_files = len(text_files)
        
        for file_idx, file_path in enumerate(text_files, 1):
            print(f"\n🔸 Traitement du fichier [{file_idx}/{total_files}] : {os.path.basename(file_path)}")
            corpus_list = create_conversation_list(file_path=file_path)

            for i, corpus in enumerate(corpus_list, 1):
                try:
                    embedding = calculate_embeddings(corpus)
                    save_embedding(corpus=corpus, embedding=embedding, cursor=cur)
                    success_count += 1
                
                    # Afficher un aperçu
                    preview = corpus[:50] + "..." if len(corpus) > 50 else corpus
                    print(f"✓ [{i}/{len(corpus_list)}] {preview}")
                
                except Exception as e:
                    error_count += 1
                    print(f"✗ [{i}/{len(corpus_list)}] ERREUR: {e}")
# Out:
# ======================================================================
# ⚙️  TRAITEMENT DES EMBEDDINGS
# ======================================================================
#
# 🔸 Traitement du fichier [1/41] : 017_00000012.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\017_00000012.txt — réessayage avec cp1252
# ✓ 43 lignes extraites
# ✓ [1/43] h: U B S bonjour
# ✓ [2/43] c: oui bonjour e j'appelle je sais pas si j'appell...
# ✓ [3/43] h: je vous écoute
# ✓ [4/43] c: c'est pour
# ✓ [5/43] c: e c'est pour savoir si la fac pendant l'été e a...
# ✓ [6/43] h: e ce serait pour vous vous souhaiteriez
# ✓ [7/43] h: non
# ✓ [8/43] c: non non c'est pas pour moi
# ✓ [9/43] c: ce serait pour ma fille
# ✓ [10/43] h: oui
# ✓ [11/43] c: mais bon elle est
# ✓ [12/43] c: en seconde et
# ✓ [13/43] h: et elle souhaiterais se perfectionner
# ✓ [14/43] c: bon elle va passer en première mais
# ✓ [15/43] h: en anglais ou en espagnol pendant l'été
# ✓ [16/43] c: ouais c'est çà
# ✓ [17/43] h: oui alors e la fac de e de lettre et de langues...
# ✓ [18/43] c: ouais par contre vous pas me m'orienter vers e
# ✓ [19/43] h: vers Lorient
# ✓ [20/43] c: e
# ✓ [21/43] c: un organisme sur Vannes qui qui s'occupe de ce ...
# ✓ [22/43] h: e non à priori non je vois pas e --- e(lle) ell...
# ✓ [23/43] c: ouais et e bon elle va passer en première mais ...
# ✓ [24/43] h: ben écoutez vous avez
# ✓ [25/43] c: son espagnol
# ✓ [26/43] h: un organisme qui s'appelle e "English Connectio...
# ✓ [27/43] c: ouais
# ✓ [28/43] h: e du coté de la place de la république là e sin...
# ✓ [29/43] c: ouais
# ✓ [30/43] h: e mais bon autrement je peux pas vraiment vous ...
# ✓ [31/43] c: et "English Connection" c'est e une entrepri(se...
# ✓ [32/43] h: je ne sais pas oh vous allez trouver ça dans le...
# ✓ [33/43] c: ouais d'accord
# ✓ [34/43] h: je sais pas
# ✓ [35/43] c: c'est place de
# ✓ [36/43] h: c'est place de la république c'est c'est tout p...
# ✓ [37/43] c: à d'accord je vous remercie
# ✓ [38/43] h: oui
# ✓ [39/43] c: madame
# ✓ [40/43] h: je vous en prie
# ✓ [41/43] h: au revoir
# ✓ [42/43] c: bonne journée
# ✓ [43/43] c: au revoir
#
# 🔸 Traitement du fichier [2/41] : 018_00000013.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\018_00000013.txt — réessayage avec cp1252
# ✓ 9 lignes extraites
# ✓ [1/9] h: U B S bonjour
# ✓ [2/9] c: oui bonjour ce serait pour savoir comment obten...
# ✓ [3/9] h: e oui je vais vous passer le secrétariat
# ✓ [4/9] c: d'accord merci
# ✓ [5/9] h: [pi]
# ✓ [6/9] h: Prenom oui
# ✓ [7/9] h: allo oui
# ✓ [8/9] h: un dossier e D E S S droit des P M E
# ✓ [9/9] h: d'accord
#
# 🔸 Traitement du fichier [3/41] : 019_00000014.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\019_00000014.txt — réessayage avec cp1252
# ✓ 12 lignes extraites
# ✓ [1/12] h: U B S bonjour
# ✓ [2/12] c: oui bonjour e j'ai appelé ce matin pour avoir e...
# ✓ [3/12] h: oui vous ê(tes) vous êtes madame c'est pour une...
# ✓ [4/12] c: voilà rappeler la date donc pour que c'était po...
# ✓ [5/12] h: d'accord je vais vous passer monsieur Nom hein
# ✓ [6/12] c: d'accord
# ✓ [7/12] h: t'as compris de quoi il s'agit Prénom hein j'ai...
# ✓ [8/12] h: allo
# ✓ [9/12] h: une une préinscription
# ✓ [10/12] h: Prénom hein
# ✓ [11/12] h: oui cette après-midi quoi
# ✓ [12/12] h: ouais ouais Prénom3 ouais
#
# 🔸 Traitement du fichier [4/41] : 020_00000015.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\020_00000015.txt — réessayage avec cp1252
# ✓ 13 lignes extraites
# ✓ [1/13] h: U B S bonjour
# ✓ [2/13] c: oui bonjour madame monsieur Nom Siemens j'aurai...
# ✓ [3/13] h: oui j'ai pas bien entendu votre nom monsieur
# ✓ [4/13] c: monsieur Nom Siemens
# ✓ [5/13] h: monsieur Nom Société Siemens
# ✓ [6/13] h: c'est ça
# ✓ [7/13] c: oui
# ✓ [8/13] c: de [pi] oui
# ✓ [9/13] h: d'accord je vais voir
# ✓ [10/13] c: merci
# ✓ [11/13] h: allo
# ✓ [12/13] h: oui j'ai en ligne monsieur Nom de la société Si...
# ✓ [13/13] h: d'accord
#
# 🔸 Traitement du fichier [5/41] : 022_00000017.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\022_00000017.txt — réessayage avec cp1252
# ✓ 23 lignes extraites
# ✓ [1/23] h: U B S bonjour
# ✓ [2/23] c: oui bonjour est-ce que je pourrais avoir monsie...
# ✓ [3/23] h: c'est lui-même
# ✓ [4/23] c: ah bonjour j'essayais de vous appeler e j'ai eu...
# ✓ [5/23] h: où ça
# ✓ [6/23] c: à l'accueil
# ✓ [7/23] h: oui
# ✓ [8/23] c: donc voilà et c'est parce que moi je e c'est po...
# ✓ [9/23] h: ouais e
# ✓ [10/23] c: en première année
# ✓ [11/23] c: et e elle m'a donné un numéro de code
# ✓ [12/23] h: ouais
# ✓ [13/23] c: et quand je fais ce numéro de code on me dit co...
# ✓ [14/23] h: e attendez attendez parce que là je suis pas à ...
# ✓ [15/23] c: e oui 0 1 26 0 4
# ✓ [16/23] h: 0 1 26 0 4 ouais
# ✓ [17/23] c: et dans combien de temps
# ✓ [18/23] h: e ben dans deux minutes trois minutes là
# ✓ [19/23] c: deux minutes trois minutes
# ✓ [20/23] h: ouais
# ✓ [21/23] c: ok
# ✓ [22/23] h: allez au revoir madame
# ✓ [23/23] c: au revoir
#
# 🔸 Traitement du fichier [6/41] : 023_00000018.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\023_00000018.txt — réessayage avec cp1252
# ✓ 14 lignes extraites
# ✓ [1/14] h: U B S bonjour
# ✓ [2/14] c: oui bonjour excusez moi de vous déranger est ce...
# ✓ [3/14] h: Prénom Nom elle travaille où c'est
# ✓ [4/14] c: ah ben écoutez j'ai j'ai e je sais pas j'ai sim...
# ✓ [5/14] h: hum
# ✓ [6/14] c: e c'est marqué e boulot donc je suppose que je ...
# ✓ [7/14] h: vous pouvez me dire le bureau ou alors e
# ✓ [8/14] h: la pièce
# ✓ [9/14] c: non
# ✓ [10/14] c: je e je suis désolée j'ai simplement le 0 2 97 ...
# ✓ [11/14] h: 0 2 97 0 1
# ✓ [12/14] c: 27 25
# ✓ [13/14] h: là je vais chercher je sais qu'il y est pas
# ✓ [14/14] c: merci
#
# 🔸 Traitement du fichier [7/41] : 024_00000019.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\024_00000019.txt — réessayage avec cp1252
# ✓ 104 lignes extraites
# ✓ [1/104] h: I U P sciences de gestion bonjour
# ✓ [2/104] h: e Prénom Nom
# ✓ [3/104] h: c'est Prénom2 il
# ✓ [4/104] h: oui oui
# ✓ [5/104] h: paraît que tu as des sujets d'examen
# ✓ [6/104] h: oui
# ✓ [7/104] h: qui urgent
# ✓ [8/104] h: e ben oui
# ✓ [9/104] h: c'est pour quand
# ✓ [10/104] h: e ben écoute e pour demain après-midi j'en ai u...
# ✓ [11/104] h: demain après-midi
# ✓ [12/104] h: t'en as un
# ✓ [13/104] h: oui
# ✓ [14/104] h: e demain
# ✓ [15/104] h: e tu veux qu?on fasse ça demain matin
# ✓ [16/104] h: e c'est combien de pages e
# ✓ [17/104] h: e alors attends tu es e après il y en a un autr...
# ✓ [18/104] h: ah il y a un autre pour lundi
# ✓ [19/104] h: oui
# ✓ [20/104] h: c'est quoi
# ✓ [21/104] h: bon
# ✓ [22/104] h: c'est qu'est-ce qu'il y a
# ✓ [23/104] h: c'est recto verso à agrafer ou il y a des
# ✓ [24/104] h: e c'est # et il y a
# ✓ [25/104] h: il y a des agrafages et des recto verso et des ...
# ✓ [26/104] h: e ouais mais cinq six pages c'est agrafé quoi
# ✓ [27/104] h: oui oui oui oui oui
# ✓ [28/104] h: ouais ouais ouais c'est pas des A3 e des e des ...
# ✓ [29/104] h: en A3 e ou et cetera # e
# ✓ [30/104] h: ah non non non non non non non non non non # no...
# ✓ [31/104] h: tu veux qu'on voie [pronounce=voye] ça demain m...
# ✓ [32/104] h: ah ben écoute demain matin Prénom2 si tu veux
# ✓ [33/104] h: c'est pour demain après-midi
# ✓ [34/104] h: oui
# ✓ [35/104] h: il est quelle heure là # deux heures e deux heu...
# ✓ [36/104] h: nous on peut faire ça demain matin hein
# ✓ [37/104] h: tu as les sujets là avec toi
# ✓ [38/104] h: oui
# ✓ [39/104] h: ouais demain matin eh je vais aller au courrier...
# ✓ [40/104] h: comme tu veux
# ✓ [41/104] h: faut que j'appelle e
# ✓ [42/104] h: ce que je peux te
# ✓ [43/104] h: Prénom3 aussi
# ✓ [44/104] h: en revanche
# ✓ [45/104] h: ben
# ✓ [46/104] h: ouais
# ✓ [47/104] h: dans un premier temps faut que j'appelle Prénom...
# ✓ [48/104] h: ouais #
# ✓ [49/104] h: et puis e dans un deuxième temps # il faut que ...
# ✓ [50/104] h: ouais
# ✓ [51/104] h: et # donc e
# ✓ [52/104] h: [bb] mon pauvre Prénom2 ouais
# ✓ [53/104] h: et Prénom4 sait pas faire
# ✓ [54/104] h: ben Prénom4 il est pas là # Prénom 4 il a fait ...
# ✓ [55/104] h: oui mais si on fait demain
# ✓ [56/104] h: ben si demain matin il pourra faire
# ✓ [57/104] h: et ben à ce moment là c'est Prénom4 qu'est au c...
# ✓ [58/104] h: de # ben il connaît le code lui
# ✓ [59/104] h: et la dernière
# ✓ [60/104] h: et et t()
# ✓ [61/104] h: fois c'est lui qu'avait remplacé sa femme quand...
# ✓ [62/104] h: et ben alors on on on demande à ce moment là à ...
# ✓ [63/104] h: on verra ça
# ✓ [64/104] h: demain mat(in)
# ✓ [65/104] h: et pis ouais pis demain si si tu tu tu as un pr...
# ✓ [66/104] h: ouais
# ✓ [67/104] h: ça passe avant hein là # là là il y a des prior...
# ✓ [68/104] h: oui
# ✓ [69/104] h: t'es bien obligé de foutre des priorités à des ...
# ✓ [70/104] h: [bb] je sais bien parce que e je
# ✓ [71/104] h: ouais # ben ouais
# ✓ [72/104] h: sais bien hein
# ✓ [73/104] h: les examens c'est # un cours tu peux le déplace...
# ✓ [74/104] h: le problème mais un examen le mec
# ✓ [75/104] h: ben oui mais un exa(men) un exa(men) # non non
# ✓ [76/104] h: il a buché il est prêt
# ✓ [77/104] h: ouais et # enfin bon
# ✓ [78/104] h: oui oui # oui oui # et surtout que bon
# ✓ [79/104] h: Prénom3 était au courant je lui avais dit qu'en...
# ✓ [80/104] h: hum
# ✓ [81/104] h: mais bon elle fait pas elle est malade elle est...
# ✓ [82/104] h: bon ben
# ✓ [83/104] h: bon ben
# ✓ [84/104] h: t'inquiète bon si lui il peut pas moi je le fer...
# ✓ [85/104] h: bon écoute on # on voit cet après-midi il est p...
# ✓ [86/104] h: il est pas là
# ✓ [87/104] h: que je sache un p(eu)
# ✓ [88/104] h: mais je vais prévenir Prénom5 que déjà il mette
# ✓ [89/104] h: ça
# ✓ [90/104] h: voilà
# ✓ [91/104] h: sur le programme de demain matin
# ✓ [92/104] h: voilà demain matin et qu'on fasse ça
# ✓ [93/104] h: et je téléphone à mon collègue
# ✓ [94/104] h: demain
# ✓ [95/104] h: ouais
# ✓ [96/104] h: matin pour savoir s'il est là au cas où il y au...
# ✓ [97/104] h: souci
# ✓ [98/104] h: un cheese e qu'il
# ✓ [99/104] h: oui
# ✓ [100/104] h: soit prêt pour me rendre service
# ✓ [101/104] h: ouais d'accord ok
# ✓ [102/104] h: allez salut
# ✓ [103/104] h: Prénom ciao
# ✓ [104/104] h: merci Prénom2
#
# 🔸 Traitement du fichier [8/41] : 027_0000001c.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\027_0000001c.txt — réessayage avec cp1252
# ✓ 35 lignes extraites
# ✓ [1/35] h: U B S bonjour
# ✓ [2/35] c: oui bonjour c'est monsieur Nom j'ai ma fille qu...
# ✓ [3/35] h: elle a passé son e quel DEUG e monsieur
# ✓ [4/35] c: le DEUG de e a() ad() administration économique...
# ✓ [5/35] h: donc c'est chez nous alors e ouais
# ✓ [6/35] c: sociale hein
# ✓ [7/35] h: donc c'est à rue de la Loi c'est Vannes centre
# ✓ [8/35] h: ouais c'est ça oui
# ✓ [9/35] c: parce que ouais parce
# ✓ [10/35] h: que les les sciences ils sont partis à Tohannic...
# ✓ [11/35] c: ah oui
# ✓ [12/35] h: donc c'est pour ça il faut nous préciser le DEU...
# ✓ [13/35] h: ouais donc elle
# ✓ [14/35] c: oui A E S elle a eu oui
# ✓ [15/35] h: peut revenir quand elle veut elle peut venir qu...
# ✓ [16/35] h: [pi]
# ✓ [17/35] c: e c'est ouvert aujourd'hui par exemple
# ✓ [18/35] h: comment
# ✓ [19/35] c: aujourd'hui c'est ouvert par exemple
# ✓ [20/35] h: ah oui oui c'est ouvert hein jusqu'à dix sept h...
# ✓ [21/35] c: jusqu'à dix sept heures trente [pi]
# ✓ [22/35] h: enfin moi je vais partir tout à l'heure à seize...
# ✓ [23/35] h: je suis en congé
# ✓ [24/35] c: oui [rire]
# ✓ [25/35] h: mais e elle va passer à quelle heure
# ✓ [26/35] c: ben e(lle) elle est sur la route de Rennes e po...
# ✓ [27/35] h: ben sinon elle
# ✓ [28/35] c: ben je sais pas bientôt
# ✓ [29/35] h: s'adresse e au secrétariat hein qu'elle s'inqui...
# ✓ [30/35] c: d'accord ben je vais lui dire qu'elle peut pass...
# ✓ [31/35] h: ouais ouais ouais ben e et a dix si il y a pers...
# ✓ [32/35] c: d'accord
# ✓ [33/35] h: voilà
# ✓ [34/35] h: au revoir # [pi]
# ✓ [35/35] c: et bien je vous remercie
#
# 🔸 Traitement du fichier [9/41] : 028_0000001d.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\028_0000001d.txt — réessayage avec cp1252
# ✓ 104 lignes extraites
# ✓ [1/104] h: U B S allo
# ✓ [2/104] h: oui e Prénom
# ✓ [3/104] h: ouais
# ✓ [4/104] h: e j'ai en communication là une personne qui a u...
# ✓ [5/104] h: un souci avec une inscription
# ✓ [6/104] h: ouais
# ✓ [7/104] h: ouais ben passe-la moi ouais
# ✓ [8/104] h: d'accord
# ✓ [9/104] h: Ok
# ✓ [10/104] h: allo
# ✓ [11/104] c: allo
# ✓ [12/104] h: bonjour madame
# ✓ [13/104] c: bonjour excusez-moi de vous déranger
# ✓ [14/104] h: je vous en prie
# ✓ [15/104] c: e j'aurais voulu avoir des précisions s'il vous...
# ✓ [16/104] h: hm
# ✓ [17/104] c: e sur internet en fait # e la préinscription do...
# ✓ [18/104] h: oui
# ✓ [19/104] c: tout c'est bien passé
# ✓ [20/104] h: oui
# ✓ [21/104] c: e et il y avait une inscription en accès libre ...
# ✓ [22/104] h: e la validation de e d'un voeu
# ✓ [23/104] c: oui voilà
# ✓ [24/104] h: parmi les trois voeux
# ✓ [25/104] h: que vous avez effectués e
# ✓ [26/104] c: [pi] oui voilà
# ✓ [27/104] h: enfin trois voeux ou
# ✓ [28/104] h: bien d() [pi] un ou un deux voilà e
# ✓ [29/104] c: ouais j'a() je non j'en avais fait qu'un en fai...
# ✓ [30/104] h: et vous voulez le valider
# ✓ [31/104] c: ouais voilà en fait non non tout c'est bien pas...
# ✓ [32/104] h: hm
# ✓ [33/104] c: et e hier par curiosité j'ai voulu voir e si je...
# ✓ [34/104] h: hm
# ✓ [35/104] c: et e quand j'ai voulu regarder e et e c'était p...
# ✓ [36/104] h: ou bien e vous le referez e lorsque
# ✓ [37/104] c: donc je voulais savoir si c'était normal
# ✓ [38/104] h: ça va la connexion va ré(ouvir) se réouvrir à l...
# ✓ [39/104] c: d'accord
# ✓ [40/104] h: donc e lorsque vous allez réouvrir
# ✓ [41/104] c: hm hm
# ✓ [42/104] h: donc il va vous redemander de e confirmer le vo...
# ✓ [43/104] h: un dossier mais bon on vous enverra le dossier ...
# ✓ [44/104] c: d'accord
# ✓ [45/104] h: # oui # ah ok # bon allo
# ✓ [46/104] c: allo
# ✓ [47/104] h: donc vous allez # valider
# ✓ [48/104] c: oui
# ✓ [49/104] h: confirmer le bac et à ce moment là vous aurez u...
# ✓ [50/104] c: d'accord donc c'est normal en fait qu'on ne qu'...
# ✓ [51/104] h: e peut-être ça a pas été pris mais bon ceux qui...
# ✓ [52/104] c: d'accord
# ✓ [53/104] h: parce qu'il y en a qui l'ont pas fait
# ✓ [54/104] c: d'accord
# ✓ [55/104] h: e
# ✓ [56/104] c: voilà [pi] c'est tout ce que je voulais savoir ...
# ✓ [57/104] h: non non il y en a il y en a beaucoup qui
# ✓ [58/104] c: de pas avoir
# ✓ [59/104] h: qui ont pas fait ça ceux qui étaient candidat e...
# ✓ [60/104] h: et ils savaient pas
# ✓ [61/104] c: hm hm
# ✓ [62/104] h: si il fallait valider ou attendre les résultats...
# ✓ [63/104] h: d'accord parce que ben moi
# ✓ [64/104] c: et de tout ça
# ✓ [65/104] c: j'avais validé c'est pour ça et e ben je je voy...
# ✓ [66/104] h: ben je vais regarder quand même e e c'est quoi ...
# ✓ [67/104] c: alors hop attendez 0 6
# ✓ [68/104] h: 0 6
# ✓ [69/104] c: F
# ✓ [70/104] h: non non mais votre votre numéro de téléphone pa...
# ✓ [71/104] h: que là j'ai j'ai du monde et
# ✓ [72/104] c: ah pardon
# ✓ [73/104] h: je vais m'en occuper et je vous rappelle
# ✓ [74/104] h: si j'ai le temps
# ✓ [75/104] c: alors
# ✓ [76/104] c: 0 2 97
# ✓ [77/104] h: ouais
# ✓ [78/104] c: 76
# ✓ [79/104] h: ouais
# ✓ [80/104] c: 40
# ✓ [81/104] h: 40
# ✓ [82/104] c: XX
# ✓ [83/104] h: XX # 0 2 97 76 40 XX vous êtes e
# ✓ [84/104] c: madam(e) mademoiselle Nom
# ✓ [85/104] h: N O M
# ✓ [86/104] c: voilà
# ✓ [87/104] h: alors donc là je vais prendre votre code en mêm...
# ✓ [88/104] c: c'est ce que j'allais vous donner tout à l'heur...
# ✓ [89/104] h: [rire] [pi] je comptais rappeler tout de suite ...
# ✓ [90/104] c: 0 6
# ✓ [91/104] h: ouais
# ✓ [92/104] c: R
# ✓ [93/104] h: R
# ✓ [94/104] c: P
# ✓ [95/104] h: R P
# ✓ [96/104] c: M
# ✓ [97/104] h: 0 6 R P M
# ✓ [98/104] c: X X
# ✓ [99/104] h: 0 6 R P M X X
# ✓ [100/104] c: voilà
# ✓ [101/104] h: Ok
# ✓ [102/104] c: ben je vous remercie
# ✓ [103/104] h: à votre service à tout à l'heure au revoir
# ✓ [104/104] c: au revoir
#
# 🔸 Traitement du fichier [10/41] : 029_0000001e.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\029_0000001e.txt — réessayage avec cp1252
# ✓ 8 lignes extraites
# ✓ [1/8] h: U B S bonjour
# ✓ [2/8] c: allo oui bonjour je voulais juste avoir un peti...
# ✓ [3/8] h: e
# ✓ [4/8] c: e je voulais vous demander e est ce que vous sa...
# ✓ [5/8] h: # e # attendez je vais voir si
# ✓ [6/8] h: si
# ✓ [7/8] c: d'accord merci
# ✓ [8/8] h: si il y a quelque chose #
#
# 🔸 Traitement du fichier [11/41] : 030_0000001f.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\030_0000001f.txt — réessayage avec cp1252
# ✓ 6 lignes extraites
# ✓ [1/6] h: U B S bonjour
# ✓ [2/6] c: oui bonjour Prénom Nom au service scolarité de ...
# ✓ [3/6] h: e vous avez fait le 725
# ✓ [4/6] c: oui c'est ça
# ✓ [5/6] h: # ne quittez pas je vais voir
# ✓ [6/6] c: merci
#
# 🔸 Traitement du fichier [12/41] : 037_00000026.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\037_00000026.txt — réessayage avec cp1252
# ✓ 7 lignes extraites
# ✓ [1/7] h: U B S Bonjour
# ✓ [2/7] c: oui bonjour madame e j'aurais aimé savoir e où ...
# ✓ [3/7] h: du D A E U ah je sais pas c'est avec qui
# ✓ [4/7] c: e ben je sais pas je vous ai téléph(oné) enfin ...
# ✓ [5/7] h: e conservez je vais demander # à qu() à partir ...
# ✓ [6/7] c: c'est à dix huit heures
# ✓ [7/7] h: et comme moi je viens d'arriver là je sais pas ...
#
# 🔸 Traitement du fichier [13/41] : 038_00000027.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\038_00000027.txt — réessayage avec cp1252
# ✓ 35 lignes extraites
# ✓ [1/35] h: U B S bonjour
# ✓ [2/35] h: oui salut Prénom
# ✓ [3/35] h: ah c'est Prénom
# ✓ [4/35] h: e tu vas essayer de voir je sais pas avec qui s...
# ✓ [5/35] h: ben oui
# ✓ [6/35] h: repro(graphie)
# ✓ [7/35] h: ce soir il doit y avoir une réunion sur le D A ...
# ✓ [8/35] h: oui [pi] oui
# ✓ [9/35] h: [pi]
# ✓ [10/35] h: c'est pas ici
# ✓ [11/35] h: non c'est rue de la Loi
# ✓ [12/35] h: oh je je pense parce que
# ✓ [13/35] h: écoute là je sais qui c'est ici oui
# ✓ [14/35] h: ah oui oui ben je te passe la b() la dame elle ...
# ✓ [15/35] h: d'accord ben passe-la moi
# ✓ [16/35] h: ok
# ✓ [17/35] h: # allo
# ✓ [18/35] c: allo bonjour monsieur
# ✓ [19/35] h: e b() non c'est une dame
# ✓ [20/35] c: ah pardon excusez-moi madame [rire] pardon
# ✓ [21/35] h: non non
# ✓ [22/35] c: e j'aimerais savoir e j'ai une réunion ce soir ...
# ✓ [23/35] h: c'est vous qui avez appelé tout à l'heure
# ✓ [24/35] c: oui
# ✓ [25/35] c: ça a ça a coupé ou je sais
# ✓ [26/35] h: on a été coupé
# ✓ [27/35] c: pas
# ✓ [28/35] h: parce que je me renseignais si si c'est bien ru...
# ✓ [29/35] c: c'est un rue de la Loi hein
# ✓ [30/35] h: oui c'est rue de la Loi la réunion
# ✓ [31/35] c: et e ben c'est un grand bâtiment c'est ce sera ...
# ✓ [32/35] h: oui c'est indiqué oui oui oui
# ✓ [33/35] c: très bien merci beaucoup madame
# ✓ [34/35] h: au revoir madame
# ✓ [35/35] c: au revoir
#
# 🔸 Traitement du fichier [14/41] : 045_0000002e.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\045_0000002e.txt — réessayage avec cp1252
# ✓ 6 lignes extraites
# ✓ [1/6] h: U B S bonjour
# ✓ [2/6] c: bonjour madame excusez moi de vous déranger e e...
# ✓ [3/6] h: oui
# ✓ [4/6] c: de droit et je voulais savoir si les diplômes e...
# ✓ [5/6] h: je vais vous passer la personne concernée
# ✓ [6/6] c: merci
#
# 🔸 Traitement du fichier [15/41] : 047_00000030.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\047_00000030.txt — réessayage avec cp1252
# ✓ 39 lignes extraites
# ✓ [1/39] h: U B S bonjour
# ✓ [2/39] c: oui bonjour madame e j'appelais pour avoir un p...
# ✓ [3/39] h: des concours administratifs
# ✓ [4/39] c: ouais
# ✓ [5/39] h: si on avait un programme sur ça
# ✓ [6/39] c: voilà oui oui
# ✓ [7/39] h: [pi] on a pas de programme pour e
# ✓ [8/39] h: je l'avais [pi]
# ✓ [9/39] h: est ce qu'il y aurait pas des concours administ...
# ✓ [10/39] h: e des concours administratifs e ouais il y a un...
# ✓ [11/39] c: allo
# ✓ [12/39] h: ouais c'est quels concours vous parlez madame
# ✓ [13/39] c: e donc e s(oit) soit adjoint administratif ou r...
# ✓ [14/39] h: ah non c'est pas ça c'est pas ici chez nous non
# ✓ [15/39] c: non c'est pas vous ne faîtes pas de préparation...
# ✓ [16/39] h: ah non c'est nous on a une préparation interne ...
# ✓ [17/39] c: ah d'accord
# ✓ [18/39] h: ouais ouais
# ✓ [19/39] c: d'accord non non moi je cherchais e si vous vou...
# ✓ [20/39] h: il y a le CNED sinon e
# ✓ [21/39] c: ouais et je sais aussi que à Rennes il y a une ...
# ✓ [22/39] h: ouais
# ✓ [23/39] c: e donc j'ai trouvé ça dans
# ✓ [24/39] h: donc faudrait que vous appeliez le S U I O ça à...
# ✓ [25/39] c: c'est le le quoi
# ✓ [26/39] h: le Service Universitaire de l'Information et de...
# ✓ [27/39] c: 0 1 27 0 0
# ✓ [28/39] h: voilà c'est le Service Universitaire de l'Infor...
# ✓ [29/39] c: d'accord
# ✓ [30/39] h: e on ne sait pas tout quoi
# ✓ [31/39] c: très bien
# ✓ [32/39] h: donc le Service
# ✓ [33/39] c: je vous remerc(ie)
# ✓ [34/39] h: de l'Information et de l'Orientation lui il doi...
# ✓ [35/39] c: d'accord très bien
# ✓ [36/39] h: voilà
# ✓ [37/39] c: je vous remercie
# ✓ [38/39] c: au revoir
# ✓ [39/39] h: à votre service au revoir
#
# 🔸 Traitement du fichier [16/41] : 048_00000031.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\048_00000031.txt — réessayage avec cp1252
# ✓ 27 lignes extraites
# ✓ [1/27] h: U B S Bonjour
# ✓ [2/27] c: oui bonjour madame e j'aurais souhaité parler à...
# ✓ [3/27] h: madame Nom conservez je vais voir si e # ah ben...
# ✓ [4/27] c: ah bon parce que on m'a donné ce numéro
# ✓ [5/27] h: elle est là que le lundi et le mardi
# ✓ [6/27] c: ah d'accord très bien parce qu'on m'a donné un ...
# ✓ [7/27] h: oui oui je vais vous donner le numéro de téléph...
# ✓ [8/27] c: ouais d'accord
# ✓ [9/27] h: hein
# ✓ [10/27] h: conservez
# ✓ [11/27] c: d'accord
# ✓ [12/27] h: # alors là elle est là le lundi et le mardi tou...
# ✓ [13/27] c: d'accord
# ✓ [14/27] h: alors madame Nom madame Nom Madame mais je ne s...
# ✓ [15/27] c: je crois que c'est Prénom
# ✓ [16/27] h: oui c'est Prénom c'est ça #
# ✓ [17/27] c: mais je crois qu'on m'a donné l'autre numéro he...
# ✓ [18/27] h: ah bon quel numéro vous avez quel
# ✓ [19/27] c: c'est pas gentil [rire]
# ✓ [20/27] h: numéro vous avez
# ✓ [21/27] c: j'ai le 88 0 5 49 # on m'a dit d'essayer soit l...
# ✓ [22/27] h: Nom Prénom alors sur Lorient
# ✓ [23/27] c: oui
# ✓ [24/27] h: le 88 0 5 49
# ✓ [25/27] c: hein c'est ça hein
# ✓ [26/27] h: d'accord c'est celui là # voilà au revoir
# ✓ [27/27] c: d'accord très bien je vous remercie madame au r...
#
# 🔸 Traitement du fichier [17/41] : 052_00000035.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\052_00000035.txt — réessayage avec cp1252
# ✓ 7 lignes extraites
# ✓ [1/7] h: U B S Bonjour
# ✓ [2/7] c: bonjour madame excusez-moi de vous déranger j'a...
# ✓ [3/7] h: # oui alors attendez je vais vous
# ✓ [4/7] c: et
# ✓ [5/7] h: passer la
# ✓ [6/7] h: personne
# ✓ [7/7] c: ouais [rire]
#
# 🔸 Traitement du fichier [18/41] : 053_00000036.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\053_00000036.txt — réessayage avec cp1252
# ✓ 20 lignes extraites
# ✓ [1/20] h: U B S bonjour
# ✓ [2/20] c: oui bonjour [pi] j'aurais aimé savoir si les di...
# ✓ [3/20] h: e j'ai pas compris vous p() [rire] oui
# ✓ [4/20] c: donc en fait il y a un diplôme qui a été envoyé...
# ✓ [5/20] h: est-ce que à oui au rectorat
# ✓ [6/20] h: c'est sur Lorient
# ✓ [7/20] c: ouais
# ✓ [8/20] h: ça
# ✓ [9/20] c: hein là je suis à Lorient
# ✓ [10/20] h: non c'est à Vannes
# ✓ [11/20] c: ouais ben ouais ouais ouais
# ✓ [12/20] h: et en quelle filière
# ✓ [13/20] c: A E S de deux mille deux
# ✓ [14/20] h: alors attendez je vais vous passer la personne ...
# ✓ [15/20] c: oui # [pi]
# ✓ [16/20] h: [pi]
# ✓ [17/20] c: [pi]
# ✓ [18/20] h: oui allo
# ✓ [19/20] h: oui c'est pour toi Prénom
# ✓ [20/20] h: merci
#
# 🔸 Traitement du fichier [19/41] : 054_00000037.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\054_00000037.txt — réessayage avec cp1252
# ✓ 21 lignes extraites
# ✓ [1/21] h: U B S bonjour
# ✓ [2/21] c: oui bonjour madame e j'ai inscrit par e par e c...
# ✓ [3/21] h: internet
# ✓ [4/21] c: int(ernet) bravo oui parce que actuellement j'a...
# ✓ [5/21] h: oui
# ✓ [6/21] c: on
# ✓ [7/21] c: est en train de nous installer l'A D S L donc j...
# ✓ [8/21] h: oui
# ✓ [9/21] c: [pf] et # ah je sais p(as) ah non non c'est adm...
# ✓ [10/21] h: oui alors je vais vous passer une personne qui ...
# ✓ [11/21] c: c'est gentil merci madame
# ✓ [12/21] h: # alors il ne répond pas pour le moment
# ✓ [13/21] c: d'accord
# ✓ [14/21] h: donc rappelez dix min(utes) [pi] rap(pelez)
# ✓ [15/21] c: au même numéro
# ✓ [16/21] h: e oui rappelez ici # autrement je vais vous don...
# ✓ [17/21] c: d'accord je rappelle à l'accueil ok merci
# ✓ [18/21] h: oui
# ✓ [19/21] c: à tout à l'heure
# ✓ [20/21] h: au revoir
# ✓ [21/21] c: au revoir
#
# 🔸 Traitement du fichier [20/41] : 055_00000038.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\055_00000038.txt — réessayage avec cp1252
# ✓ 7 lignes extraites
# ✓ [1/7] h: U B S bonjour
# ✓ [2/7] c: bonjour madame madame Nom s'il vous plait
# ✓ [3/7] h: [pi] ah elle s'est absentée de son bureau
# ✓ [4/7] c: ah e e bon je peux la rappeler plus tard à ce m...
# ✓ [5/7] h: oui oui oui rappelez parce qu'elle est là mais ...
# ✓ [6/7] h: hein vous pouvez tout à l'heure au revoir
# ✓ [7/7] c: OK merci au revoir
#
# 🔸 Traitement du fichier [21/41] : 057_0000003a.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\057_0000003a.txt — réessayage avec cp1252
# ✓ 34 lignes extraites
# ✓ [1/34] h: U B S bonjour
# ✓ [2/34] c: oui bonjour madame excusez-moi de vous déranger...
# ✓ [3/34] h: I() I U P sciences de gestion
# ✓ [4/34] c: comment
# ✓ [5/34] h: I U P sciences de gestion
# ✓ [6/34] c: non pour savoir ce que vous aviez en en master ...
# ✓ [7/34] h: oui conservez je vais vous passer # je v() [pi]...
# ✓ [8/34] c: d'accord
# ✓ [9/34] h: # qu'est-ce qui fait où c'est que j'ai mis ma f...
# ✓ [10/34] c: d'accord parce que en fait les dates d'inscript...
# ✓ [11/34] h: c'est pour les la date d'inscription c'est ça
# ✓ [12/34] c: e ouais pour s'inscrire par exemple s'il y a un...
# ✓ [13/34] h: c'est quand la date but(oir) # la date butoir e
# ✓ [14/34] c: il y a un master qui l'intéresse et il voudrait...
# ✓ [15/34] h: # S G E G # oui
# ✓ [16/34] c: comment
# ✓ [17/34] h: [pi] c'est en S() S G E G
# ✓ [18/34] c: ça veux dire quoi # S
# ✓ [19/34] h: en droit
# ✓ [20/34] c: c'est en économie
# ✓ [21/34] h: économie et gestion
# ✓ [22/34] c: gestion en fait
# ✓ [23/34] h: donc
# ✓ [24/34] h: [pi]
# ✓ [25/34] c: et justement je
# ✓ [26/34] c: je voulais e savoir ce qu'il y avait en fait co...
# ✓ [27/34] h: # oui ben conservez je vais vous passer une aut...
# ✓ [28/34] c: d'accord
# ✓ [29/34] h: [pi]
# ✓ [30/34] c: merci
# ✓ [31/34] h: [pi] # [pi] il doit peut-être savoir [pi] qui e...
# ✓ [32/34] h: oui
# ✓ [33/34] h: oui je te passe une communication
# ✓ [34/34] h: d'accord
#
# 🔸 Traitement du fichier [22/41] : 058_0000003b.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\058_0000003b.txt — réessayage avec cp1252
# ✓ 13 lignes extraites
# ✓ [1/13] h: U B S bonjour
# ✓ [2/13] c: oui bonjour madame madame Nom de Brest je vous ...
# ✓ [3/13] h: en quelle filière
# ✓ [4/13] c: en droit
# ✓ [5/13] h: en droit oui je vais vous passer Prénom Nom
# ✓ [6/13] c: ah oui là je suis pas en droit
# ✓ [7/13] h: si vous êtes en droit
# ✓ [8/13] c: parce que je
# ✓ [9/13] h: si si mais à l'accueil
# ✓ [10/13] h: je vous passe la pers(onne)
# ✓ [11/13] c: ah d'accord oui d'accord
# ✓ [12/13] h: personne de la scolar(ité) [pronounce=scora] sc...
# ✓ [13/13] c: d'accord merci
#
# 🔸 Traitement du fichier [23/41] : 059_0000003c.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\059_0000003c.txt — réessayage avec cp1252
# ✓ 7 lignes extraites
# ✓ [1/7] h: U B S bonjour
# ✓ [2/7] c: oui bonjour je vous appelle au sujet des résult...
# ✓ [3/7] h: oui je vais vous passer une personne conservez ...
# ✓ [4/7] c: d'accord merci [rire]
# ✓ [5/7] h: # oui
# ✓ [6/7] h: oui je te je te passe une communication
# ✓ [7/7] h: ouais
#
# 🔸 Traitement du fichier [24/41] : 060_0000003d.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\060_0000003d.txt — réessayage avec cp1252
# ✓ 3 lignes extraites
# ✓ [1/3] h: U B S bonjour
# ✓ [2/3] c: oui bonjour madame j'aurais voulu avoir des ren...
# ✓ [3/3] h: Nom oui [pi] oui conservez je vais vous passer ...
#
# 🔸 Traitement du fichier [25/41] : 065_00000042.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\065_00000042.txt — réessayage avec cp1252
# ✓ 3 lignes extraites
# ✓ [1/3] h: U B S bonjour
# ✓ [2/3] c: bonjour ici Prénom Nom est ce que je pourrais a...
# ✓ [3/3] h: # oui
#
# 🔸 Traitement du fichier [26/41] : 067_00000044.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\067_00000044.txt — réessayage avec cp1252
# ✓ 42 lignes extraites
# ✓ [1/42] h: U B S bonjour
# ✓ [2/42] c: oui bonjour madame madame Nom à l'appareil je b...
# ✓ [3/42] h: monsieur Nom2 vous avez essayé son bureau
# ✓ [4/42] h: direct
# ✓ [5/42] c: oui
# ✓ [6/42] c: oui
# ✓ [7/42] h: ah oui ok
# ✓ [8/42] c: il répond pas
# ✓ [9/42] h: non ben il doit pas être
# ✓ [10/42] h: là pour le moment
# ✓ [11/42] c: c'est() c'est e
# ✓ [12/42] c: 0 1 26 58 c'est ça
# ✓ [13/42] h: monsieur Nom2 attendez je regarde
# ✓ [14/42] h: bien
# ✓ [15/42] c: 0 1 26
# ✓ [16/42] c: 26 58
# ✓ [17/42] h: # e je cherche parce que j'ai pas le numéro en ...
# ✓ [18/42] c: hm
# ✓ [19/42] h: Nom2 Nom2 Nom2 # oui c'est ça alors attendez
# ✓ [20/42] c: bon
# ✓ [21/42] h: c'est ça c'est ça oui
# ✓ [22/42] c: c'est ça et madame Nom3 j'ai pas son numéro dir...
# ✓ [23/42] h: madame Nom3
# ✓ [24/42] c: oui
# ✓ [25/42] h: six cent quarante neuf à la fin
# ✓ [26/42] c: c'est six cent quarante n(euf) # e combien
# ✓ [27/42] h: e six cent quarante neuf
# ✓ [28/42] c: 26 49 c'est
# ✓ [29/42] h: en tout ah bien oui mais nous on fait 26 9
# ✓ [30/42] c: ça d'accord # oui
# ✓ [31/42] h: oui oui oui je sais vous bon je fais les mêmes ...
# ✓ [32/42] h: ouais 0 2 97
# ✓ [33/42] c: bon ok c'est elle qui est responsable
# ✓ [34/42] c: de la première année e A E S
# ✓ [35/42] h: oui mais je peux vous passer le secrétariat aut...
# ✓ [36/42] c: bon mais je vais non écoutez je vais l'appeler ...
# ✓ [37/42] h: d'accord
# ✓ [38/42] c: je vais l'appeler
# ✓ [39/42] c: directement
# ✓ [40/42] h: au revoir
# ✓ [41/42] c: merci madame
# ✓ [42/42] c: au revoir
#
# 🔸 Traitement du fichier [27/41] : 068_00000045.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\068_00000045.txt — réessayage avec cp1252
# ✓ 54 lignes extraites
# ✓ [1/54] h: U B S bonjour
# ✓ [2/54] c: e bonjour c'est Prénom Nom de l'ADEFOP
# ✓ [3/54] h: oui
# ✓ [4/54] c: c'est Prénom2
# ✓ [5/54] h: non c'est pas Prénom2 c'est Prénom3
# ✓ [6/54] c: Prénom3
# ✓ [7/54] h: Prénom3 Nom3 qui est à Tohannic mais qui est là...
# ✓ [8/54] c: ah d'accord ben voilà j'ai toutes les explicati...
# ✓ [9/54] h: voilà pourquoi c'est pas la même voix oui
# ✓ [10/54] c: [rire] [pf] [rire]
# ✓ [11/54] c: non parce que je connais Prénom2 et Prénom4 à l...
# ✓ [12/54] h: voilà
# ✓ [13/54] c: donc
# ✓ [14/54] c: e moi j'appelais parce que ce soir à six heures...
# ✓ [15/54] h: oui c'est ici
# ✓ [16/54] c: on a réservé des salles est-ce que parce que je...
# ✓ [17/54] h: oui
# ✓ [18/54] c: est ce que on voudrait afficher des on voudrait...
# ✓ [19/54] h: oui
# ✓ [20/54] c: e il doit y avoir des supports non
# ✓ [21/54] h: e oui il faut que j'en parle à Prénom4 parce qu...
# ✓ [22/54] c: ou je rappelle Prénom4 vous préférez
# ✓ [23/54] h: e
# ✓ [24/54] c: ou
# ✓ [25/54] c: Prénom4 me rappelle tout à l'heure
# ✓ [26/54] h: oui enfin toute manière je crois qu'il est il e...
# ✓ [27/54] c: oui
# ✓ [28/54] h: donc e à une heure et demie ben je peux lui dir...
# ✓ [29/54] c: oui parce qu'il doit y avoir des panneaux à met...
# ✓ [30/54] h: ouais # je vais prendre votre numéro
# ✓ [31/54] c: à l'extérieur ou quelque chose comme ça
# ✓ [32/54] c: alors mon numéro c'est 0 2 97 oh ben voilà que ...
# ✓ [33/54] h: oh oui ben on se téléphone
# ✓ [34/54] h: pas beaucoup
# ✓ [35/54] c: ça va mal
# ✓ [36/54] c: non 0 2 97 0 1 72 XX
# ✓ [37/54] h: 72
# ✓ [38/54] h: XX
# ✓ [39/54] c: Prénom Nom
# ✓ [40/54] h: Prénom Nom
# ✓ [41/54] h: oui d'accord
# ✓ [42/54] c: à l'ADEFOP
# ✓ [43/54] h: d'accord c'est lui qui s'occupe de de ça
# ✓ [44/54] c: d'accord
# ✓ [45/54] h: d'accord
# ✓ [46/54] h: et vous rep()
# ✓ [47/54] c: merci beaucoup
# ✓ [48/54] h: et vous reprenez à quelle heure
# ✓ [49/54] c: oh moi je m'arrête une demie heure de midi à mi...
# ✓ [50/54] h: d'accord
# ✓ [51/54] c: voilà
# ✓ [52/54] h: d'accord
# ✓ [53/54] c: au revoir
# ✓ [54/54] h: au revoir
#
# 🔸 Traitement du fichier [28/41] : 072_00000049.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\072_00000049.txt — réessayage avec cp1252
# ✓ 32 lignes extraites
# ✓ [1/32] h: U B S bonjour
# ✓ [2/32] c: oui Prénom Nom bonjour e j'aimerais joindre e m...
# ✓ [3/32] h: Monsieur Nom2 Prénom2 oui
# ✓ [4/32] c: c'est possible
# ✓ [5/32] h: oui je vais regarder s'il est dans son bureau o...
# ✓ [6/32] c: merci c'est madame Nom3
# ✓ [7/32] h: oui
# ✓ [8/32] c: c'est ça
# ✓ [9/32] h: je vais vous passer madame
# ✓ [10/32] c: oui d'accord
# ✓ [11/32] h: Nom3 hein elle va vous dire si e
# ✓ [12/32] c: merci
# ✓ [13/32] h: #
# ✓ [14/32] h: attends est-ce que tu sais où sont les grands p...
# ✓ [15/32] c: d'accord
# ✓ [16/32] h: je lui d(is)
# ✓ [17/32] c: je rappelle
# ✓ [18/32] c: dans un instant peut être
# ✓ [19/32] h: oui d'ici un petit quart d'heure
# ✓ [20/32] c: est-ce qu'il y a une ligne directe pour le son ...
# ✓ [21/32] h: e oui
# ✓ [22/32] c: ou est-ce
# ✓ [23/32] h: 0 2 97
# ✓ [24/32] c: oui
# ✓ [25/32] h: 0 1
# ✓ [26/32] c: 26
# ✓ [27/32] h: 26 73
# ✓ [28/32] c: ok
# ✓ [29/32] h: voilà
# ✓ [30/32] c: merci
# ✓ [31/32] h: au revoir monsieur
# ✓ [32/32] c: bonne journée
#
# 🔸 Traitement du fichier [29/41] : 073_0000004a.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\073_0000004a.txt — réessayage avec cp1252
# ✓ 34 lignes extraites
# ✓ [1/34] h: U B S bonjour
# ✓ [2/34] c: oui bonjour madame j'aurais voulu le secrétaria...
# ✓ [3/34] h: e oui qu'avez v() dans quelle filière
# ✓ [4/34] c: e [pf] [pi] je je en fait j'ai reçu un un appel...
# ✓ [5/34] h: [pi]
# ✓ [6/34] c: sur un portable c'est
# ✓ [7/34] c: très mal indiqué je j'arrive pas à comprendre l...
# ✓ [8/34] h: ça doit être Nom Prénom
# ✓ [9/34] c: e c'est possible oui
# ✓ [10/34] h: oui Nom2 Prénom2
# ✓ [11/34] c: peut-être oui vous
# ✓ [12/34] h: et sur v() le papier c'est marqué quoi # vous a...
# ✓ [13/34] c: non c'est c'est sur mon portable j'ai eu un un ...
# ✓ [14/34] h: de droit publique
# ✓ [15/34] c: oui droit publique mais j'arrive pas e j'arrive...
# ✓ [16/34] h: [pi] le nom
# ✓ [17/34] c: entendre quoi j'ai j'ai pas compris le nom
# ✓ [18/34] h: oui [pi] # licence maîtrise ou
# ✓ [19/34] c: maîtrise
# ✓ [20/34] h: maîtrise # Nom Prénom conservez je vais vous la...
# ✓ [21/34] c: merci beaucoup
# ✓ [22/34] h: #
# ✓ [23/34] h: allo
# ✓ [24/34] h: c'est pour toi tu as dû appeler quelqu'un sur u...
# ✓ [25/34] h: non
# ✓ [26/34] h: non ben il a ton il pense que c'est toi en
# ✓ [27/34] h: ah bon
# ✓ [28/34] h: oui
# ✓ [29/34] h: c'est un beau mec
# ✓ [30/34] h: moi je
# ✓ [31/34] h: ou quoi
# ✓ [32/34] h: vois pas il m'a eue par téléphone
# ✓ [33/34] h: oh ben merde alors
# ✓ [34/34] h: oui zut
#
# 🔸 Traitement du fichier [30/41] : 074_0000004b.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\074_0000004b.txt — réessayage avec cp1252
# ✓ 8 lignes extraites
# ✓ [1/8] h: U B S bonjour
# ✓ [2/8] c: boujour madame madame Nom s'il vous plait
# ✓ [3/8] h: Prénom Nom
# ✓ [4/8] c: oui
# ✓ [5/8] h: oui conservez je vais vous la passer #
# ✓ [6/8] h: oui allo
# ✓ [7/8] h: c'est pour toi Prénom
# ✓ [8/8] h: ouais
#
# 🔸 Traitement du fichier [31/41] : 075_0000004c.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\075_0000004c.txt — réessayage avec cp1252
# ✓ 23 lignes extraites
# ✓ [1/23] h: U B S bonjour
# ✓ [2/23] c: oui bonjour madame j'aurais voulu parler à mada...
# ✓ [3/23] h: e attendez si elle est dans son bureau là elle ...
# ✓ [4/23] c: ah bon d'accord
# ✓ [5/23] h: je vais essayer de vous la passer
# ✓ [6/23] c: merci beaucoup
# ✓ [7/23] h: e Nom Prénom alors 12 624 conservez hein
# ✓ [8/23] c: oui
# ✓ [9/23] h: #
# ✓ [10/23] h: [pi] en euros # non elle a dû s'absenter de son...
# ✓ [11/23] c: oui
# ✓ [12/23] h: hein alors Nom Prénom c'est le 0 2 97
# ✓ [13/23] c: ouais
# ✓ [14/23] h: 0 1
# ✓ [15/23] c: ouais
# ✓ [16/23] h: XX XX
# ✓ [17/23] c: c'est ce que j'ai fait
# ✓ [18/23] h: ah oui c'est retombé à l'accueil
# ✓ [19/23] c: voilà
# ✓ [20/23] h: donc elle a dû s'absenter de son bureau mais e(...
# ✓ [21/23] c: d'accord entendu
# ✓ [22/23] h: # au revoir
# ✓ [23/23] c: merci beaucoup au revoir
#
# 🔸 Traitement du fichier [32/41] : 079_00000050.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\079_00000050.txt — réessayage avec cp1252
# ✓ 28 lignes extraites
# ✓ [1/28] h: U B S bonjour
# ✓ [2/28] c: oui bonjour madame Prénom Nom Crédit Agricole N...
# ✓ [3/28] h: oui en quelle filière
# ✓ [4/28] c: elle est en licence professionnelle gestion des...
# ✓ [5/28] h: oui
# ✓ [6/28] c: dans les
# ✓ [7/28] c: PMO
# ✓ [8/28] h: je vais vous passer la personne
# ✓ [9/28] h: concernée donc secrétariat
# ✓ [10/28] c: d'accord merci
# ✓ [11/28] h: c'est Prénom3 Nom3 # donc j'espère qu'elle est ...
# ✓ [12/28] c: d'accord
# ✓ [13/28] r: est occupé veuillez rappeler ultérieurement ou ...
# ✓ [14/28] h: oui sa ligne est occupée mais je vais vous donn...
# ✓ [15/28] c: d'accord alors attendez je note
# ✓ [16/28] h: un crayon oui bien-sûr
# ✓ [17/28] c: oui allez-y
# ✓ [18/28] h: 0 2 97
# ✓ [19/28] c: oui
# ✓ [20/28] h: 0 1
# ✓ [21/28] c: oui
# ✓ [22/28] h: 26 XX
# ✓ [23/28] c: d'accord
# ✓ [24/28] h: Prénom3 Nom3
# ✓ [25/28] c: merci madame
# ✓ [26/28] c: d'accord merci beaucoup madame
# ✓ [27/28] h: au revoir madame
# ✓ [28/28] c: au revoir
#
# 🔸 Traitement du fichier [33/41] : 083_00000054.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\083_00000054.txt — réessayage avec cp1252
# ✓ 19 lignes extraites
# ✓ [1/19] h: U B S bonjour
# ✓ [2/19] c: oui bonjour madame pourrais-je parler à monsieu...
# ✓ [3/19] h: monsieur Nom
# ✓ [4/19] c: oui
# ✓ [5/19] h: # je vais rechercher je vais regarder s'il est ...
# ✓ [6/19] c: e il travaille e au niveau informatique
# ✓ [7/19] h: ah c'est Prénom Nom
# ✓ [8/19] c: voilà tout à fait madame
# ✓ [9/19] h: oui alors attendez lui il est en # en sciences ...
# ✓ [10/19] h: son bureau
# ✓ [11/19] c: merci
# ✓ [12/19] h: # là vous êtes au droit # e Nom Prénom alors 0 ...
# ✓ [13/19] c: oui
# ✓ [14/19] h: 0 1
# ✓ [15/19] c: oui
# ✓ [16/19] h: 70 XX
# ✓ [17/19] c: 70 XX # très bien je
# ✓ [18/19] h: voilà au revoir
# ✓ [19/19] c: vous remercie madame au revoir
#
# 🔸 Traitement du fichier [34/41] : 087_00000058.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\087_00000058.txt — réessayage avec cp1252
# ✓ 19 lignes extraites
# ✓ [1/19] h: U B S bonjour
# ✓ [2/19] c: oui bonjour madame j'aurais voulu parler à Prén...
# ✓ [3/19] h: alors Prénom Nom
# ✓ [4/19] c: parce que j'ai essayé de l'appeler tout à l'heu...
# ✓ [5/19] h: ah oui donc c'est ça retombe à l'accueil
# ✓ [6/19] h: [pi] conservez
# ✓ [7/19] c: oui c'est pourquoi
# ✓ [8/19] h: je vais essayer de mon côté
# ✓ [9/19] c: d'accord
# ✓ [10/19] h: # non e(lle) elle a dû
# ✓ [11/19] c: # si tu veux
# ✓ [12/19] h: s'absenter de son bureau pour le moment
# ✓ [13/19] c: d'accord bon ben je
# ✓ [14/19] h: patientez
# ✓ [15/19] c: réessaierai plus tard
# ✓ [16/19] h: oui voilà oui [rire]
# ✓ [17/19] c: merci au
# ✓ [18/19] h: au revoir
# ✓ [19/19] c: revoir
#
# 🔸 Traitement du fichier [35/41] : 090_0000005b.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\090_0000005b.txt — réessayage avec cp1252
# ✓ 11 lignes extraites
# ✓ [1/11] h: U B S bonjour
# ✓ [2/11] c: oui bonjour e j'aurais voulu savoir je postule ...
# ✓ [3/11] h: oui
# ✓ [4/11] c: et donc je postule pour l'IGER l'année prochain...
# ✓ [5/11] h: en A E S
# ✓ [6/11] c: non en écono(mie) en science licence sciences é...
# ✓ [7/11] h: oui alors conservez je vais vous passer Prénom ...
# ✓ [8/11] h: oui
# ✓ [9/11] h: oui c'est pour toi
# ✓ [10/11] h: Prénom
# ✓ [11/11] h: oui merci
#
# 🔸 Traitement du fichier [36/41] : 096_00000061.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\096_00000061.txt — réessayage avec cp1252
# ✓ 40 lignes extraites
# ✓ [1/40] h: U B S bonjour
# ✓ [2/40] c: oui bonjour # j'aurais voulu avoir quelques pré...
# ✓ [3/40] h: première
# ✓ [4/40] c: quand
# ✓ [5/40] h: année de DEUG de droit quand est-ce que les rés...
# ✓ [6/40] c: oui et ben et puis comment on peut les avoir pa...
# ✓ [7/40] h: vous êtes très loin #
# ✓ [8/40] h: alors je vais vous
# ✓ [9/40] c: peut-être internet
# ✓ [10/40] h: donner la date déjà dans un premier te(mps)
# ✓ [11/40] c: oui date
# ✓ [12/40] h: première année de DEUG de droit ce sera le merc...
# ✓ [13/40] h: vers
# ✓ [14/40] c: mercredi
# ✓ [15/40] h: dix-sept heures
# ✓ [16/40] c: vingt-trois juin deux mille quatre à dix-sept h...
# ✓ [17/40] h: bien et donc vous souhaiteriez les recevoir par...
# ✓ [18/40] c: e oui et puis les éventuellement la possibilité...
# ✓ [19/40] h: ah non je
# ✓ [20/40] h: crois pas
# ✓ [21/40] c: non
# ✓ [22/40] h: oui bon je vais e vous mettre en relation avec ...
# ✓ [23/40] c: merci
# ✓ [24/40] h: #
# ✓ [25/40] h: eh Prénom # Prénom2 n'est pas là # Prénom2 n'es...
# ✓ [26/40] c: e
# ✓ [27/40] h: e vous pouvez rappeler je vous donne son numéro
# ✓ [28/40] h: direct
# ✓ [29/40] c: oui
# ✓ [30/40] h: e donc c'est le 0 2 97 0 1 26 XX
# ✓ [31/40] c: le 26 0 1 26
# ✓ [32/40] h: 0 2 97 hein 0 1 26 XX
# ✓ [33/40] c: d'accord
# ✓ [34/40] h: vous rappelez
# ✓ [35/40] c: je note
# ✓ [36/40] h: d'ici un quart d'heure vingt minutes
# ✓ [37/40] c: d'accord merci
# ✓ [38/40] h: voilà
# ✓ [39/40] c: au revoir
# ✓ [40/40] h: au revoir
#
# 🔸 Traitement du fichier [37/41] : 098_00000063.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\098_00000063.txt — réessayage avec cp1252
# ✓ 19 lignes extraites
# ✓ [1/19] h: U B S bonjour
# ✓ [2/19] c: oui bonjour madame excusez moi de vous déranger...
# ✓ [3/19] h: oui
# ✓ [4/19] c: s'il vous plait
# ✓ [5/19] c: [pf] j'ai ma fille qui s'est inscrite chez vous...
# ✓ [6/19] h: hm hm
# ✓ [7/19] c: et elle n'a pas eu confirmation
# ✓ [8/19] h: alors e donc elle a formulé trois voeux au dépa...
# ✓ [9/19] c: ouais oui je pense oui
# ✓ [10/19] h: oui et avant le six juin elle a dû valider un d...
# ✓ [11/19] c: non justement elle a pas pu le faire
# ✓ [12/19] h: elle n'a pas pu le faire bon alors elle souhait...
# ✓ [13/19] c: oui
# ✓ [14/19] h: en quoi
# ✓ [15/19] c: [pf] e licence un A E S
# ✓ [16/19] h: d'accord e je vais vous passer la e je vais vou...
# ✓ [17/19] c: d'accord ben je vous remercie beaucoup madame
# ✓ [18/19] h: # e madame le le poste du secrétariat d(e) de s...
# ✓ [19/19] c: d'accord
#
# 🔸 Traitement du fichier [38/41] : 101_00000066.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\101_00000066.txt — réessayage avec cp1252
# ✓ 42 lignes extraites
# ✓ [1/42] h: U B S bonjour
# ✓ [2/42] c: oui bonjour e j'aurais souhaité e avoir Prénom ...
# ✓ [3/42] h: oui # au site à Lorient à quel numéro
# ✓ [4/42] c: au 0 2 97 87
# ✓ [5/42] h: 87
# ✓ [6/42] c: 29 XX
# ✓ [7/42] h: d'accord
# ✓ [8/42] c: il n'a pas de numéro e n()
# ✓ [9/42] h: je vais voir
# ✓ [10/42] c: à l'atelier
# ✓ [11/42] h: je vais voir s'il est à l'atelier hein
# ✓ [12/42] c: et il y a pas de numéro à l'atelier là
# ✓ [13/42] h: si si si je vais voir s'il y est je l'ai aperçu...
# ✓ [14/42] c: d'accord merci
# ✓ [15/42] h: # non ça ne répond pas
# ✓ [16/42] h: je vais lui laisser un
# ✓ [17/42] c: et # et
# ✓ [18/42] c: ben écoutez je vais je vais noter son numéro pa...
# ✓ [19/42] h: d'accord c'est le 0 1 27 XX
# ✓ [20/42] c: ben c'est c'est ce que j'ai 0 1 27 XX donc c'es...
# ✓ [21/42] h: voilà
# ✓ [22/42] c: quoi
# ✓ [23/42] h: exactement
# ✓ [24/42] c: d'accord donc ça c'est le numéro de l'atelier
# ✓ [25/42] h: oui
# ✓ [26/42] h: je vais
# ✓ [27/42] c: ok
# ✓ [28/42] h: laisser un message su le de() portable s'il est...
# ✓ [29/42] c: et qu'il qu'il
# ✓ [30/42] h: voilà
# ✓ [31/42] c: m'appelle
# ✓ [32/42] c: avant avant onze heures et demie parce que aprè...
# ✓ [33/42] h: avant onze heures et demie
# ✓ [34/42] c: s'il peut
# ✓ [35/42] h: d'accord
# ✓ [36/42] h: c'est monsieur Nom2
# ✓ [37/42] c: très bien
# ✓ [38/42] c: c'est ça
# ✓ [39/42] h: # très bien bon ben c'est noté
# ✓ [40/42] c: merci
# ✓ [41/42] h: merci au revoir
# ✓ [42/42] c: au revoir
#
# 🔸 Traitement du fichier [39/41] : 102_00000067.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\102_00000067.txt — réessayage avec cp1252
# ✓ 64 lignes extraites
# ✓ [1/64] h: U B S bonjour
# ✓ [2/64] c: oui bonjour madame excusez moi de vous déranger...
# ✓ [3/64] h: les maîtrise de droit de re() droit j'ai rien p...
# ✓ [4/64] c: ah d'accord
# ✓ [5/64] h: non # non #
# ✓ [6/64] h: et
# ✓ [7/64] c: bon
# ✓ [8/64] h: faudrait appeler madame Nom dans le courant de ...
# ✓ [9/64] c: oui oui oui
# ✓ [10/64] h: là elle est pas dans son bureau hein
# ✓ [11/64] c: d'accord parce que là les résultat seront affic...
# ✓ [12/64] h: ben justement je ne sais pas je vous dis
# ✓ [13/64] h: ma
# ✓ [14/64] c: vous savez pas
# ✓ [15/64] h: ma collègue m'a rien donné non elle m'a donné p...
# ✓ [16/64] c: ah oui d'accord
# ✓ [17/64] h: oui
# ✓ [18/64] c: oui # e oui ça peut être dans la journée même e...
# ✓ [19/64] h: aujourd'hui
# ✓ [20/64] c: non
# ✓ [21/64] c: oui non
# ✓ [22/64] h: ah sûrement pas
# ✓ [23/64] h: ah non
# ✓ [24/64] c: ah non
# ✓ [25/64] c: ah non je ne
# ✓ [26/64] h: ah non elle m'aurait
# ✓ [27/64] c: non non
# ✓ [28/64] h: donné depuis longtemps hein
# ✓ [29/64] c: ah oui d'accord
# ✓ [30/64] h: ah oui
# ✓ [31/64] c: d'accord
# ✓ [32/64] h: oui oui oui
# ✓ [33/64] h: oui [pf] ah oui
# ✓ [34/64] c: d'accord oui oui oui
# ✓ [35/64] h: non là j'ai rien donc c'est sûrement e sûrement...
# ✓ [36/64] c: ah pas cette
# ✓ [37/64] h: ah ben non
# ✓ [38/64] c: semaine
# ✓ [39/64] h: je pense pas parce qu'elle m'a donné pour les l...
# ✓ [40/64] c: e
# ✓ [41/64] h: et alors attendez pour les licences e qu'est-ce...
# ✓ [42/64] h: donc e ça
# ✓ [43/64] c: donc oui
# ✓ [44/64] h: peut pas être avant pour les e comment pour les...
# ✓ [45/64] c: parce que
# ✓ [46/64] h: elle m'aurait donné
# ✓ [47/64] c: normalement
# ✓ [48/64] c: normalement c'était vendredi pour les maîtrises...
# ✓ [49/64] h: je ne sais pas du tout non je vous dis
# ✓ [50/64] h: moi
# ✓ [51/64] c: non
# ✓ [52/64] h: elle m'a donné pour les licences vendredi
# ✓ [53/64] c: ah oui
# ✓ [54/64] h: oui
# ✓ [55/64] c: e
# ✓ [56/64] h: ouais mais bon vous l'appelez au 0 1 26 XX et p...
# ✓ [57/64] c: ah d'accord
# ✓ [58/64] h: oui
# ✓ [59/64] c: oui oui
# ✓ [60/64] h: voilà
# ✓ [61/64] c: bon
# ✓ [62/64] c: bien ben je vous remercie
# ✓ [63/64] h: au revoir madame
# ✓ [64/64] c: allez au revoir
#
# 🔸 Traitement du fichier [40/41] : 104_00000069.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\104_00000069.txt — réessayage avec cp1252
# ✓ 26 lignes extraites
# ✓ [1/26] h: U B S bonjour
# ✓ [2/26] c: e oui bonjour j'aurais souhaité avoir le secrét...
# ✓ [3/26] h: oui c'est vous êtes déjà en D U ou c'est pour a...
# ✓ [4/26] c: non c'est parce que nous avons transmis un doss...
# ✓ [5/26] h: oui
# ✓ [6/26] c: et je voulais savoir ben d'une part s'il était ...
# ✓ [7/26] h: d'accord
# ✓ [8/26] c: puis e
# ✓ [9/26] c: quand est-ce qu'on aurait la réponse et comment...
# ✓ [10/26] h: après d'accord
# ✓ [11/26] c: des inscriptions voilà oui
# ✓ [12/26] h: inscription administrative oui
# ✓ [13/26] c: oui
# ✓ [14/26] h: e # c'est pour vous madame
# ✓ [15/26] c: c'est pour ma fille
# ✓ [16/26] h: vous me donnez son nom s'il vous plaît
# ✓ [17/26] c: Nom Prénom
# ✓ [18/26] h: N O M
# ✓ [19/26] c: voilà oui oui
# ✓ [20/26] h: Nom Prénom donc e dossier de dérogation pour en...
# ✓ [21/26] c: oui
# ✓ [22/26] h: je vais vous passer ma collègue hein
# ✓ [23/26] c: merci
# ✓ [24/26] h: oui
# ✓ [25/26] h: alors madame je suppose Nom appelle pour sa fil...
# ✓ [26/26] h: d'accord je te remercie # ouais
#
# 🔸 Traitement du fichier [41/41] : 105_0000006a.txt
# ✓ 1 lignes extraites
# ✓ [1/1] h: U B S bonjour

# %% [markdown]
# Résumé

# %%
print("\n" + "=" * 70)
print("📊 RÉSUMÉ")
print("=" * 70)
print(f"✓ Succès: {success_count}")
print(f"✗ Erreurs: {error_count}")
print(f"📦 Total sauvegardé: {success_count}")

# Créer l'index maintenant que les données sont insérées
if success_count > 0:
    print("\n🔧 Création de l'index de recherche...")
    with psycopg.connect(db_connection_str) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute("""
                CREATE INDEX IF NOT EXISTS embeddings_embedding_idx 
                ON embeddings USING ivfflat (embedding vector_cosine_ops)
                WITH (lists = 100)
            """)
            print("✓ Index de recherche créé")
# Out:
# ======================================================================
# 📊 RÉSUMÉ
# ======================================================================
# ✓ Succès: 1062
# ✗ Erreurs: 0
# 📦 Total sauvegardé: 1062
#
# 🔧 Création de l'index de recherche...
# ✓ Index de recherche créé

# %% [markdown]
# Test de recherche

# %%
if success_count > 0:
    print("\n" + "=" * 70)
    print("🔍 TEST DE RECHERCHE")
    print("=" * 70)
    
    test_query = "stage anglais espagnol"
    print(f"Requête: '{test_query}'")
    
    try:
        results = similar_corpus(test_query, db_connection_str, top_k=3)
        print(f"\n📌 Top 3 résultats:")
        for doc_id, corpus, similarity in results:
            preview = corpus[:60] + "..." if len(corpus) > 60 else corpus
            print(f"  [Score: {similarity:.4f}] {preview}")
    except Exception as e:
        print(f"❌ Erreur: {e}")
# Out:
# ======================================================================
# 🔍 TEST DE RECHERCHE
# ======================================================================
# Requête: 'stage anglais espagnol'
#
# 📌 Top 3 résultats:
#   [Score: 0.7764] h: en anglais ou en espagnol pendant l'été
#   [Score: 0.6054] h: si si mais à l'accueil
#   [Score: 0.6016] h: faut que j'appelle e

# %% [markdown]
# Fonction de recherche interactive

# %%
def recherche_interactive(query: str, top_k: int = 5):
    """
    Fonction pour faire des recherches facilement dans le notebook
    """
    print(f"🔍 Recherche: '{query}'")
    print("-" * 70)
    
    try:
        results = similar_corpus(query, db_connection_str, top_k=top_k)
        
        if not results:
            print("Aucun résultat trouvé")
            return
        
        for i, (doc_id, corpus, similarity) in enumerate(results, 1):
            print(f"\n📄 Résultat {i} (Score: {similarity:.4f})")
            print(f"   ID: {doc_id}")
            print(f"   Texte: {corpus[:100]}{'...' if len(corpus) > 100 else ''}")
            
    except Exception as e:
        print(f"❌ Erreur: {e}")

# Exemple d'utilisation :
# recherche_interactive("votre requête ici", top_k=3)

print("✓ Fonction de recherche interactive disponible")
print("  Usage: recherche_interactive('votre requête', top_k=5)")
# Out:
# ✓ Fonction de recherche interactive disponible
#   Usage: recherche_interactive('votre requête', top_k=5)
