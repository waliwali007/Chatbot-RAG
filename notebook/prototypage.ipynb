# %% [markdown]
# Importer les librairies dans le notebook

# %%
pip install ollama
# Out:
# Collecting ollama
#   Using cached ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting httpx>=0.27 (from ollama)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pydantic>=2.9 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from ollama) (2.12.5)
# Collecting anyio (from httpx>=0.27->ollama)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from httpx>=0.27->ollama) (2025.11.12)
# Collecting httpcore==1.* (from httpx>=0.27->ollama)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from httpx>=0.27->ollama) (3.11)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.27->ollama)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ahmwa\onedrive\bureau\projets\ai\chatbot\venv\lib\site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Using cached ollama-0.6.1-py3-none-any.whl (14 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.4 kB ? eta -:--:--
#    ---------- ---------------------------- 30.7/113.4 kB 660.6 kB/s eta 0:00:01
#    ------------------------ -------------- 71.7/113.4 kB 653.6 kB/s eta 0:00:01
#    -------------------------------------- 113.4/113.4 kB 825.0 kB/s eta 0:00:00
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: h11, anyio, httpcore, httpx, ollama
# Successfully installed anyio-4.12.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 ollama-0.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ollama
import psycopg
from psycopg import Cursor
import os
import glob

# %% [markdown]
# Configuration

# %%
data_dir = os.path.join(os.path.dirname(os.getcwd()), "data")

OLLAMA_MODEL = "mistral:latest"

db_connection_str = "postgresql://postgres:postgres@localhost:5433/ai"

print(f"✓ Dossier de données : {data_dir}")
print(f"✓ Modèle Ollama : {OLLAMA_MODEL}")
print(f"✓ Configuration chargée")
# Out:
# ✓ Dossier de données : c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data
# ✓ Modèle Ollama : mistral:latest
# ✓ Configuration chargée

# %% [markdown]
# Test de connexion Ollama

# %%
try:
    models = ollama.list()
    
    # Extraire correctement tous les noms disponibles
    if isinstance(models, dict) and 'models' in models:
        model_names = [m.get('name') or m.get('model') for m in models['models']]
    elif isinstance(models, list):
        model_names = [m.get('name') or m.get('model') for m in models]
    else:
        model_names = []

    if OLLAMA_MODEL in model_names:
        print(f"✓ Modèle {OLLAMA_MODEL} disponible")
    else:
        print(f"⚠️  Modèle {OLLAMA_MODEL} non trouvé")
        print("   Modèles disponibles :", ", ".join(model_names))

    # Test embeddings
    print("\n🧪 Test d'embedding...")
    test_response = ollama.embeddings(model=OLLAMA_MODEL, prompt="test")
    print(f"✓ Ollama fonctionne correctement")

except Exception as e:
    print(f"❌ Erreur de connexion à Ollama : {e}")
# Out:
# ⚠️  Modèle mistral:latest non trouvé
#    Modèles disponibles :
#
# 🧪 Test d'embedding...
# ✓ Ollama fonctionne correctement

# %% [markdown]
# Fonctions utilitaires

# %%
def create_conversation_list(file_path: str) -> list[str]:
    """Lit le fichier avec le bon encodage et filtre les lignes"""
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
    except UnicodeDecodeError:
        print(f"⚠️  Encodage UTF-8 invalide pour {file_path} — réessayage avec cp1252")
        with open(file_path, "r", encoding="cp1252", errors="replace") as file:
            text = file.read()

    text_list = text.split("\n")
    filtered_list = [
        chaine.removeprefix("     ")
        for chaine in text_list
        if not chaine.startswith("<") and chaine.strip()
    ]
    print(f"✓ {len(filtered_list)} lignes extraites")
    return filtered_list


def calculate_embeddings(corpus: str) -> list[float]:
    """Calcule les embeddings avec Ollama"""
    if not corpus or not corpus.strip():
        raise ValueError("Le corpus ne peut pas être vide")
    
    # Appel à Ollama pour générer l'embedding
    response = ollama.embeddings(
        model=OLLAMA_MODEL,
        prompt=corpus
    )
    return response["embedding"]


def save_embedding(corpus: str, embedding: list[float], cursor: Cursor) -> None:
    """Sauvegarde le corpus et son embedding"""
    cursor.execute(
        '''INSERT INTO embeddings (corpus, embedding) VALUES (%s, %s)''',
        (corpus, embedding)
    )


def similar_corpus(input_corpus: str, db_connection_str: str, top_k: int = 5) -> list[tuple]:
    """
    Recherche les textes similaires dans la base de données
    """
    query_embedding = calculate_embeddings(input_corpus)
    
    with psycopg.connect(db_connection_str) as conn:
        with conn.cursor() as cur:
            cur.execute("""
                SELECT id, corpus, 
                       1 - (embedding <=> %s::vector) as similarity
                FROM embeddings
                ORDER BY embedding <=> %s::vector
                LIMIT %s
            """, (query_embedding, query_embedding, top_k))
            
            return cur.fetchall()

print("✓ Fonctions définies")
# Out:
# ✓ Fonctions définies

# %% [markdown]
# Création de la base de données

# %%
print("=" * 70)
print("🚀 CRÉATION DE LA BASE D'EMBEDDINGS")
print("=" * 70)

with psycopg.connect(db_connection_str) as conn:
    conn.autocommit = True
    with conn.cursor() as cur:
        # Supprimer la table si elle existe
        cur.execute("""DROP TABLE IF EXISTS embeddings""")
        print("✓ Table existante supprimée")
        
        # Créer l'extension pgvector
        cur.execute("""CREATE EXTENSION IF NOT EXISTS vector""")
        print("✓ Extension pgvector créée")
        
        # Créer la table avec VECTOR(768)
        cur.execute("""
            CREATE TABLE IF NOT EXISTS embeddings (
                id SERIAL PRIMARY KEY, 
                corpus TEXT,
                embedding VECTOR(768)
            )
        """)
        print("✓ Table embeddings créée avec VECTOR(768)")
        
        # Créer un index pour accélérer les recherches
        cur.execute("""
            CREATE INDEX IF NOT EXISTS embeddings_embedding_idx 
            ON embeddings USING ivfflat (embedding vector_cosine_ops)
            WITH (lists = 100)
        """)
        print("✓ Index de recherche créé")
# Out:
# ======================================================================
# 🚀 CRÉATION DE LA BASE D'EMBEDDINGS
# ======================================================================
# ✓ Table existante supprimée
# ✓ Extension pgvector créée
# ✓ Table embeddings créée avec VECTOR(768)
# ✓ Index de recherche créé

# %% [markdown]
# Chargement des fichiers

# %%
print("\n" + "=" * 70)
print("📂 CHARGEMENT DES DONNÉES")
print("=" * 70)

text_files = sorted(glob.glob(os.path.join(data_dir, "*.txt")))

if not text_files:
    print(f"⚠️  Aucun fichier .txt trouvé dans le dossier {data_dir}")
else:
    print(f"✓ {len(text_files)} fichier(s) trouvé(s)")
    for i, file in enumerate(text_files[:5], 1):  # Afficher les 5 premiers
        print(f"  {i}. {os.path.basename(file)}")
    if len(text_files) > 5:
        print(f"  ... et {len(text_files) - 5} autre(s)")
# Out:
# ======================================================================
# 📂 CHARGEMENT DES DONNÉES
# ======================================================================
# ✓ 41 fichier(s) trouvé(s)
#   1. 017_00000012.txt
#   2. 018_00000013.txt
#   3. 019_00000014.txt
#   4. 020_00000015.txt
#   5. 022_00000017.txt
#   ... et 36 autre(s)

# %% [markdown]
# Traitement des embeddings

# %%
print("\n" + "=" * 70)
print("⚙️  TRAITEMENT DES EMBEDDINGS")
print("=" * 70)

success_count = 0
error_count = 0

with psycopg.connect(db_connection_str) as conn:
    conn.autocommit = True
    with conn.cursor() as cur:
        total_files = len(text_files)
        
        for file_idx, file_path in enumerate(text_files, 1):
            print(f"\n🔸 Traitement du fichier [{file_idx}/{total_files}] : {os.path.basename(file_path)}")
            corpus_list = create_conversation_list(file_path=file_path)

            for i, corpus in enumerate(corpus_list, 1):
                try:
                    embedding = calculate_embeddings(corpus)
                    save_embedding(corpus=corpus, embedding=embedding, cursor=cur)
                    success_count += 1
                
                    # Afficher un aperçu
                    preview = corpus[:50] + "..." if len(corpus) > 50 else corpus
                    print(f"✓ [{i}/{len(corpus_list)}] {preview}")
                
                except Exception as e:
                    error_count += 1
                    print(f"✗ [{i}/{len(corpus_list)}] ERREUR: {e}")
# Out:
# ======================================================================
# ⚙️  TRAITEMENT DES EMBEDDINGS
# ======================================================================
#
# 🔸 Traitement du fichier [1/41] : 017_00000012.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\017_00000012.txt — réessayage avec cp1252
# ✓ 43 lignes extraites
# ✗ [1/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [2/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [3/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [4/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [5/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [6/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [7/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [8/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [9/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [10/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [11/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [12/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [13/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [14/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [15/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [16/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [17/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [18/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [19/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [20/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [21/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [22/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [23/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [24/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [25/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [26/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [27/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [28/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [29/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [30/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [31/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [32/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [33/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [34/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [35/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [36/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [37/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [38/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [39/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [40/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [41/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [42/43] ERREUR: expected 768 dimensions, not 4096
# ✗ [43/43] ERREUR: expected 768 dimensions, not 4096
#
# 🔸 Traitement du fichier [2/41] : 018_00000013.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\018_00000013.txt — réessayage avec cp1252
# ✓ 9 lignes extraites
# ✗ [1/9] ERREUR: expected 768 dimensions, not 4096
# ✗ [2/9] ERREUR: expected 768 dimensions, not 4096
# ✗ [3/9] ERREUR: expected 768 dimensions, not 4096
# ✗ [4/9] ERREUR: expected 768 dimensions, not 4096
# ✗ [5/9] ERREUR: expected 768 dimensions, not 4096
# ✗ [6/9] ERREUR: expected 768 dimensions, not 4096
# ✗ [7/9] ERREUR: expected 768 dimensions, not 4096
# ✗ [8/9] ERREUR: expected 768 dimensions, not 4096
# ✗ [9/9] ERREUR: expected 768 dimensions, not 4096
#
# 🔸 Traitement du fichier [3/41] : 019_00000014.txt
# ⚠️  Encodage UTF-8 invalide pour c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\data\019_00000014.txt — réessayage avec cp1252
# ✓ 12 lignes extraites
# ✗ [1/12] ERREUR: expected 768 dimensions, not 4096
# ✗ [2/12] ERREUR: expected 768 dimensions, not 4096
# ✗ [3/12] ERREUR: expected 768 dimensions, not 4096
# ✗ [4/12] ERREUR: expected 768 dimensions, not 4096
# ✗ [5/12] ERREUR: expected 768 dimensions, not 4096
# ✗ [6/12] ERREUR: expected 768 dimensions, not 4096
# ✗ [7/12] ERREUR: expected 768 dimensions, not 4096
# ✗ [8/12] ERREUR: expected 768 dimensions, not 4096
# ✗ [9/12] ERREUR: expected 768 dimensions, not 4096
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 19
#      17 for i, corpus in enumerate(corpus_list, 1):
#      18     try:
# ---> 19         embedding = calculate_embeddings(corpus)
#      20         save_embedding(corpus=corpus, embedding=embedding, cursor=cur)
#      21         success_count += 1
#
# Cell In[62], line 27, in calculate_embeddings(corpus)
#      24     raise ValueError("Le corpus ne peut pas être vide")
#      26 # Appel à Ollama pour générer l'embedding
# ---> 27 response = ollama.embeddings(
#      28     model=OLLAMA_MODEL,
#      29     prompt=corpus
#      30 )
#      31 return response["embedding"]
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\ollama\_client.py:417, in Client.embeddings(self, model, prompt, options, keep_alive)
#     407 def embeddings(
#     408   self,
#     409   model: str = '',
#    (...)    412   keep_alive: Optional[Union[float, str]] = None,
#     413 ) -> EmbeddingsResponse:
#     414   """
#     415   Deprecated in favor of `embed`.
#     416   """
# --> 417   return self._request(
#     418     EmbeddingsResponse,
#     419     'POST',
#     420     '/api/embeddings',
#     421     json=EmbeddingsRequest(
#     422       model=model,
#     423       prompt=prompt,
#     424       options=options,
#     425       keep_alive=keep_alive,
#     426     ).model_dump(exclude_none=True),
#     427   )
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\ollama\_client.py:129, in Client._request_raw(self, *args, **kwargs)
#     127 def _request_raw(self, *args, **kwargs):
#     128   try:
# --> 129     r = self._client.request(*args, **kwargs)
#     130     r.raise_for_status()
#     131     return r
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\ahmwa\OneDrive\Bureau\Projets\AI\Chatbot\venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
